# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../datasets/pct_pov_80_16.csv')

# %%
df = df.rename(columns={"Year":"time"})

# %%
df.head()
# Out:
#      time  Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# 0  1/1/80     12.9    10.2      9.9      14.1        10.1       9.3
# 1  1/1/81     16.0    13.1     12.8      15.9        11.9       9.1
# 2  1/1/82     15.3    12.1     13.6      14.9        12.1       8.9
# 3  1/1/83     16.2    12.6     16.1      16.0        13.9       8.5
# 4  1/1/84     16.3     9.2     17.2      16.1        13.9       9.9
#
#    Connecticut  Delaware  District of Columbia  Florida  Georgia  Hawaii  \
# 0          8.3       6.5                  12.5     11.5     12.1     8.4
# 1         10.2       7.4                  14.7     13.7     14.8     9.2
# 2         10.6       8.8                  13.9     13.4     13.1    10.6
# 3          9.8      11.6                  16.3     13.0     15.4     9.3
# 4          9.1      11.1                  16.6     16.2     18.1    10.9
#
#    Idaho  Illinois  Indiana  Iowa  Kansas  Kentucky  Louisiana  Maine  \
# 0    7.1       9.3     10.1   9.5     9.5      13.6       17.9   10.4
# 1   11.5      10.3     11.6   8.9     7.5      15.7       19.0   11.6
# 2   11.5      11.5     11.7   7.5    14.3      13.5       20.5   12.4
# 3   11.1      12.1     11.8   9.8    11.2      15.2       20.2   12.7
# 4   12.3      10.9     13.5  10.4    14.2      19.5       18.6   12.3
#
#    Maryland  Massachusetts  Michigan  Minnesota  Mississippi  Missouri  \
# 0       7.0            7.5      10.2        5.7         19.2       9.4
# 1       8.0            8.7      10.5        7.9         19.6      12.4
# 2       7.6           11.2      11.5        8.5         18.5      11.4
# 3       7.1            9.6      11.1        8.7         21.1      13.0
# 4       9.6           11.5      12.8        7.8         19.1       9.8
#
#    Montana  Nebraska  Nevada  New Hampshire  New Jersey  New Mexico  New York  \
# 0      9.7       8.7    10.4            3.7         6.3        15.3      12.5
# 1     10.3      10.5    13.0            6.1         8.2        16.6      11.1
# 2     10.3      11.5    13.2            7.2         9.9        19.7      12.7
# 3     11.7       9.6    10.1            6.4         9.4        17.8      11.9
# 4     11.9      10.3    13.0            7.3        11.2        19.7      14.2
#
#    North Carolina  North Dakota  Ohio  Oklahoma  Oregon  Pennsylvania  \
# 0            12.7           8.1  12.4      10.8     8.1           8.7
# 1            13.1           9.7  11.9      13.4     9.7          11.8
# 2            15.2          12.4  12.9      12.8    11.5          10.9
# 3            13.6          11.1  13.7      14.6    11.8          11.1
# 4            15.3          10.7  13.6      14.2    11.9          12.3
#
#    Rhode Island  South Carolina  South Dakota  Tennessee  Texas  Utah  \
# 0           9.2            15.1          10.6       13.1   11.1   7.3
# 1           8.9            12.8          10.6       12.0   13.7   6.9
# 2          11.3            15.2          10.7       11.3   13.2   8.7
# 3          11.4            14.1          14.5       14.9   13.8   8.6
# 4          11.8            14.3          13.9       14.7   14.7   9.3
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming
# 0      8.6       8.8         7.0           13.9        8.4      9.2
# 1      9.7       9.8         8.6           15.9        8.6      9.5
# 2      8.6      10.5        10.9           17.1        9.2     13.0
# 3      9.6      11.4        11.0           18.0       10.7     10.9
# 4     10.7      10.9        11.4           14.5       11.4      9.8

# %%
df['time'] = pd.to_datetime(df['time'])

# %%
df.to_csv('../datasets/df_ts_pov_final.csv')

# %%
df.head()
# Out:
#         time  Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# 0 1980-01-01     12.9    10.2      9.9      14.1        10.1       9.3
# 1 1981-01-01     16.0    13.1     12.8      15.9        11.9       9.1
# 2 1982-01-01     15.3    12.1     13.6      14.9        12.1       8.9
# 3 1983-01-01     16.2    12.6     16.1      16.0        13.9       8.5
# 4 1984-01-01     16.3     9.2     17.2      16.1        13.9       9.9
#
#    Connecticut  Delaware  District of Columbia  Florida  Georgia  Hawaii  \
# 0          8.3       6.5                  12.5     11.5     12.1     8.4
# 1         10.2       7.4                  14.7     13.7     14.8     9.2
# 2         10.6       8.8                  13.9     13.4     13.1    10.6
# 3          9.8      11.6                  16.3     13.0     15.4     9.3
# 4          9.1      11.1                  16.6     16.2     18.1    10.9
#
#    Idaho  Illinois  Indiana  Iowa  Kansas  Kentucky  Louisiana  Maine  \
# 0    7.1       9.3     10.1   9.5     9.5      13.6       17.9   10.4
# 1   11.5      10.3     11.6   8.9     7.5      15.7       19.0   11.6
# 2   11.5      11.5     11.7   7.5    14.3      13.5       20.5   12.4
# 3   11.1      12.1     11.8   9.8    11.2      15.2       20.2   12.7
# 4   12.3      10.9     13.5  10.4    14.2      19.5       18.6   12.3
#
#    Maryland  Massachusetts  Michigan  Minnesota  Mississippi  Missouri  \
# 0       7.0            7.5      10.2        5.7         19.2       9.4
# 1       8.0            8.7      10.5        7.9         19.6      12.4
# 2       7.6           11.2      11.5        8.5         18.5      11.4
# 3       7.1            9.6      11.1        8.7         21.1      13.0
# 4       9.6           11.5      12.8        7.8         19.1       9.8
#
#    Montana  Nebraska  Nevada  New Hampshire  New Jersey  New Mexico  New York  \
# 0      9.7       8.7    10.4            3.7         6.3        15.3      12.5
# 1     10.3      10.5    13.0            6.1         8.2        16.6      11.1
# 2     10.3      11.5    13.2            7.2         9.9        19.7      12.7
# 3     11.7       9.6    10.1            6.4         9.4        17.8      11.9
# 4     11.9      10.3    13.0            7.3        11.2        19.7      14.2
#
#    North Carolina  North Dakota  Ohio  Oklahoma  Oregon  Pennsylvania  \
# 0            12.7           8.1  12.4      10.8     8.1           8.7
# 1            13.1           9.7  11.9      13.4     9.7          11.8
# 2            15.2          12.4  12.9      12.8    11.5          10.9
# 3            13.6          11.1  13.7      14.6    11.8          11.1
# 4            15.3          10.7  13.6      14.2    11.9          12.3
#
#    Rhode Island  South Carolina  South Dakota  Tennessee  Texas  Utah  \
# 0           9.2            15.1          10.6       13.1   11.1   7.3
# 1           8.9            12.8          10.6       12.0   13.7   6.9
# 2          11.3            15.2          10.7       11.3   13.2   8.7
# 3          11.4            14.1          14.5       14.9   13.8   8.6
# 4          11.8            14.3          13.9       14.7   14.7   9.3
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming
# 0      8.6       8.8         7.0           13.9        8.4      9.2
# 1      9.7       9.8         8.6           15.9        8.6      9.5
# 2      8.6      10.5        10.9           17.1        9.2     13.0
# 3      9.6      11.4        11.0           18.0       10.7     10.9
# 4     10.7      10.9        11.4           14.5       11.4      9.8

# %%
df.shape
# Out:
# (40, 52)

# %% [markdown]
# ## Train and Valid

# %%
## https://stackoverflow.com/questions/26921651/how-to-delete-the-last-row-of-data-of-a-pandas-dataframe

df_train = pd.DataFrame(df.drop(df.tail(9).index))

# %%
df_train.shape
# Out:
# (31, 52)

# %%
df_val = pd.DataFrame(df.drop(df.head(30).index))

# %%
df_val.shape
# Out:
# (10, 52)

# %%
df_val.head()
# Out:
#          time  Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# 30 2010-01-01     18.9    10.5     14.1      18.3        12.9      12.1
# 31 2011-01-01     18.9    10.5     14.1      18.3        12.9      12.1
# 32 2012-01-01     21.3    12.0     12.8      21.8        12.3      12.5
# 33 2013-01-01     23.8    11.4     14.3      21.3        12.7      13.5
# 34 2014-01-01     20.6     8.7     10.7      22.9        13.6      10.2
#
#     Connecticut  Delaware  District of Columbia  Florida  Georgia  Hawaii  \
# 30          2.9      10.0                  18.0     12.5     15.0    11.3
# 31          2.9      10.0                  18.0     12.5     15.0    11.3
# 32          6.6       6.6                  14.9     12.4     14.6     8.8
# 33          6.0      12.4                  12.8     11.4     14.6    10.7
# 34          7.6      11.4                  20.4     13.4     17.7    10.7
#
#     Idaho  Illinois  Indiana  Iowa  Kansas  Kentucky  Louisiana  Maine  \
# 30   12.4      12.7     13.7  10.3    10.8      16.1       23.3   10.4
# 31   12.4      12.7     13.7  10.3    10.8      16.1       23.3   10.4
# 32   15.1      14.4     11.1  14.5     9.2      17.3       25.1   11.7
# 33   18.5      13.3     12.7  12.9    11.1      17.7       22.0   10.2
# 34   16.0      15.6     12.0  17.9    13.8      19.4       18.1   11.9
#
#     Maryland  Massachusetts  Michigan  Minnesota  Mississippi  Missouri  \
# 30       9.0            8.8      13.2       11.2         22.0      12.6
# 31       9.0            8.8      13.2       11.2         22.0      12.6
# 32       9.2            8.2      12.2       11.3         25.0      14.0
# 33       9.2            9.2      13.9       12.5         26.6      14.4
# 34       8.7            9.2      14.5       12.6         25.1      13.7
#
#     Montana  Nebraska  Nevada  New Hampshire  New Jersey  New Mexico  \
# 30     15.6      12.8    10.8            7.7         8.2        19.5
# 31     15.6      12.8    10.8            7.7         8.2        19.5
# 32     18.0      11.9    10.4            4.8         8.3        19.4
# 33     16.5      13.6     8.1            3.7         8.9        21.3
# 34     16.0      14.8    14.4            6.0         8.3        18.5
#
#     New York  North Carolina  North Dakota  Ohio  Oklahoma  Oregon  \
# 30      12.6            12.2          12.2  10.6      14.7    11.2
# 31      12.6            12.2          12.2  10.6      14.7    11.2
# 32      14.3            13.8          11.4  12.7      17.0    14.2
# 33      13.2            14.3          13.5  12.8      14.7    12.3
# 34      15.8            14.2          15.9  12.8      16.0    11.9
#
#     Pennsylvania  Rhode Island  South Carolina  South Dakota  Tennessee  \
# 30          10.4           6.7            17.0          13.2       18.4
# 31          10.4           6.7            17.0          13.2       18.4
# 32          10.6           8.1            15.6          15.2       16.9
# 33          10.1           9.1            17.3          17.0       18.3
# 34          10.5           9.0            15.2          17.3       18.1
#
#     Texas  Utah  Vermont  Virginia  Washington  West Virginia  Wisconsin  \
# 30   17.1   8.2      8.0      10.9         9.6           15.7        8.4
# 31   17.1   8.2      8.0      10.9         9.6           15.7        8.4
# 32   17.6  10.2      9.3       9.9        10.0           21.6        9.0
# 33   17.3  12.6     11.0       9.7        12.9           22.4       10.7
# 34   15.9  10.9      9.2      10.0        12.0           22.3       11.6
#
#     Wyoming
# 30     10.9
# 31     10.9
# 32     10.8
# 33     14.6
# 34     12.0

# %% [markdown]
# ## Moving onto the timeseries work

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
## Help and base code comes from: https://www.youtube.com/watch?v=axjgEgBgIY0

# %%
au = df_train[['time', 'Georgia']]
au_v = df_val[['time', 'Georgia']]

au.set_index('time', inplace=True)
au_v.set_index('time', inplace=True)

index_15_years = pd.date_range(au.index[-1], freq = 'AS', periods = 15)

# %%
mod_arima = ARIMA(au, order=(0,1,1))
model_arima_fit = mod_arima.fit()

fcast1 = model_arima_fit.forecast(15)[0]

fcast1 = pd.Series(fcast1, index=index_15_years)
fcast1 = fcast1.rename('Arima');
# Out:
# /Users/andrewroberts/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# /Users/andrewroberts/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# /Users/andrewroberts/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'

# %%
fig, ax = plt.subplots(figsize =(15,5))
chart = sns.lineplot(x='time', y = 'Georgia', data = au)
chart.set_title('AU')
fcast1.plot(ax=ax, color = 'green', marker = 'o', legend = True)
au.plot(ax=ax, color = 'blue', marker = 'o', legend = True)
au_v.plot(ax=ax, color = 'orange', marker = 'o', legend = True)
# Out:
# <AxesSubplot:title={'center':'AU'}, xlabel='time', ylabel='Georgia'>

# %% [markdown]
# ## Auto-Arima

# %%
## Help and base code comes from: https://www.youtube.com/watch?v=axjgEgBgIY0

# %%
import pmdarima as pm
from pmdarima.model_selection import train_test_split

# %%
auto_arima_mod = pm.auto_arima(au, seasonal = False, m = 4)
model_arima_fit = mod_arima.fit()

fcast2 = auto_arima_mod.predict(5)

fcast2 = pd.Series(fcast2, index=index_15_years)
fcast2 = fcast2.rename('Auto_Arima')
# Out:
# /Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/_validation.py:62: UserWarning: m (4) set for non-seasonal fit. Setting to 0
#   warnings.warn("m (%i) set for non-seasonal fit. Setting to 0" % m)
# /Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(1,0,2)(0,0,0)[0]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py", line 200, in fun_and_grad
#     self._update_fun()
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py", line 166, in _update_fun
#     self._update_fun_impl()
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py", line 73, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py", line 70, in fun_wrapped
#     return fun(x, *args)
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels/tsa/statespace/_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels/tsa/statespace/_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels/tsa/statespace/_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels/tsa/statespace/_tools.pyx", line 1284, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: Schur decomposition solver error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# /Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(2,0,2)(0,0,0)[0]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/arima.py", line 482, in fit
#     self._fit(y, X, **fit_args)
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/arima.py", line 403, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/arima.py", line 393, in _fit_wrapper
#     return arima, arima.fit(start_params=start_params,
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/mlemodel.py", line 690, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py", line 519, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/optimizer.py", line 224, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/optimizer.py", line 629, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py", line 197, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py", line 360, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py", line 200, in fun_and_grad
#     self._update_fun()
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py", line 166, in _update_fun
#     self._update_fun_impl()
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py", line 73, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py", line 70, in fun_wrapped
#     return fun(x, *args)
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py", line 501, in f
#     return -self.loglike(params, *args) / nobs
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/mlemodel.py", line 925, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "/Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/representation.py", line 985, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels/tsa/statespace/_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels/tsa/statespace/_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels/tsa/statespace/_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels/tsa/statespace/_tools.pyx", line 1284, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: Schur decomposition solver error.
#
#   warnings.warn(warning_str, ModelFitWarning)
# /Users/ae-j/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'

# %%
fig, ax = plt.subplots(figsize =(15,5))
chart = sns.lineplot(x='time', y = 'Georgia', data = au)
chart.set_title('AU')
fcast2.plot(ax=ax, color = 'green', marker = 'o', legend = True)
au.plot(ax=ax, color = 'blue', marker = 'o', legend = True)
au_v.plot(ax=ax, color = 'orange', marker = 'o', legend = True)
# Out:
# <AxesSubplot:title={'center':'AU'}, xlabel='time', ylabel='Georgia'>

# %% [markdown]
# ## Time Series with Prophet

# %%
from fbprophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
Prophet
# Out:
# fbprophet.forecaster.Prophet

# %%
au.head()
# Out:
#             Georgia
# time
# 1980-01-01     12.1
# 1981-01-01     14.8
# 1982-01-01     13.1
# 1983-01-01     15.4
# 1984-01-01     18.1

# %%
## Help and base code from https://www.youtube.com/watch?v=sCl6CXZ2xBg

# %%
## Copying and renaming 
au_c = df_train[['time', 'Georgia']].copy()
au_c.columns = ['ds', 'y']
au_c['ds'] = pd.to_datetime(au_c['ds'])

# %%
model_p = Prophet()
model_p.fit(au_c)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.

# %%
# au_c.set_index('ds', inplace=True)
# index_5_years = pd.date_range(au.index[-1], freq = 'AS', periods = 5)
# df_index_5_years = pd.DataFrame(index_5_years).copy()

# %%
future = model_p.make_future_dataframe(15, freq = 'Y')

# %%
au_c.head()
# Out:
#           ds     y
# 0 1980-01-01  12.1
# 1 1981-01-01  14.8
# 2 1982-01-01  13.1
# 3 1983-01-01  15.4
# 4 1984-01-01  18.1

# %%
#make predictions

fcast3 = model_p.predict(future)

# %%
fcast3 = pd.Series(fcast3['yhat'].values, name = 'Prophet', index = fcast3['ds'])

# %%
fcast3.head()
# Out:
# ds
# 1980-01-01    15.593833
# 1981-01-01    15.651487
# 1982-01-01    15.684120
# 1983-01-01    15.593087
# 1984-01-01    15.378427
# Name: Prophet, dtype: float64

# %%
## Add an index to this which is the datetime index

# %%
fcast3.head()
# Out:
# ds
# 2009-01-01    19.765915
# 2010-01-01    19.730041
# 2011-01-01    19.736826
# 2012-01-01    19.006064
# 2013-01-01    18.709642
# Name: Prophet, dtype: float64

# %%
fig, ax = plt.subplots(figsize =(15,5))
chart = sns.lineplot(x='time', y = 'Georgia', data = au)
chart.set_title('AU')
fcast3.plot(ax=ax, color = 'green', marker = 'o', legend = True)
au.plot(ax=ax, color = 'blue', marker = 'o', legend = True)
au_v.plot(ax=ax, color = 'orange', marker = 'o', legend = True)
# Out:
# <AxesSubplot:title={'center':'AU'}, xlabel='time', ylabel='Georgia'>

# %% [markdown]
# ### Multivariate
