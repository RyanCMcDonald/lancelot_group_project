# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# '/Users/ae-j/Documents/GA'

# %%
cd /Users/ae-j/Documents/GA/PL/project_group/lancelot_group_project
# Out:
# /Users/ae-j/Documents/GA/PL/project_group/lancelot_group_project

# %%
output_df = pd.read_csv('./data/time_series/output_df.csv', sep = '\t')

# %%
output_df.tail(10)
# Out:
#       Unnamed: 0        Year    State  Food Insecurity Rate  \
# 1499         959  2018-01-01  Wyoming                   NaN
# 1500         960  2018-12-31  Wyoming                   NaN
# 1501         961  2019-01-01  Wyoming                   NaN
# 1502         962  2020-01-01  Wyoming                   NaN
# 1503         963  2020-12-31  Wyoming                   NaN
# 1504         964  2021-12-31  Wyoming                   NaN
# 1505         965  2022-12-31  Wyoming                   NaN
# 1506         966  2023-12-31  Wyoming                   NaN
# 1507         967  2024-12-31  Wyoming                   NaN
# 1508         968  2025-12-31  Wyoming                   NaN
#
#       Prophet ForecastValue Future  Prophet ForecastValue Validation
# 1499                     12.236538                               NaN
# 1500                           NaN                          9.707053
# 1501                     11.972544                               NaN
# ...

# %%
output_df['Year'] = output_df['Year'].str.replace('2019-12-31', '2020-01-01')
output_df['Year'] = output_df['Year'].str.replace('2020-12-31', '2021-01-01')
output_df['Year'] = output_df['Year'].str.replace('2021-12-31', '2022-01-01')
output_df['Year'] = output_df['Year'].str.replace('2022-12-31', '2023-01-01')
output_df['Year'] = output_df['Year'].str.replace('2023-12-31', '2024-01-01')
output_df['Year'] = output_df['Year'].str.replace('2024-12-31', '2025-01-01')
output_df['Year'] = output_df['Year'].str.replace('2025-12-31', '2026-01-01')

# %%
output_df
# Out:
#       Unnamed: 0        Year                 State  Food Insecurity Rate  \
# 0              0  2010-01-01               Alabama             20.379104
# 1              1  2011-01-01               Alabama             19.292537
# 2              2  2012-01-01               Alabama             19.497412
# 3              3  2013-01-01               Alabama             18.569592
# 4              4  2014-01-01               Alabama             18.800626
# 5              5  2015-01-01               Alabama             18.952239
# 6              6  2016-01-01               Alabama             18.492537
# 7              7  2017-01-01               Alabama             18.092537
# 8              8  2018-01-01               Alabama             17.155224
# 9              9  2019-01-01               Alabama             17.719403
# 10            10  2010-01-01                Alaska             15.021739
# 11            11  2011-01-01                Alaska             14.573913
# ...

# %%
output_df.to_csv('./data/time_series/output_final.csv', index=False)
