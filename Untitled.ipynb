# %%
import pandas as pd
import numpy as np

# %%
poverty =pd.read_csv('./data/pct_pov_80_19.csv',)

poverty
# Out:
#     Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# 0      12.9    10.2      9.9      14.1        10.1       9.3          8.3
# 1      16.0    13.1     12.8      15.9        11.9       9.1         10.2
# 2      15.3    12.1     13.6      14.9        12.1       8.9         10.6
# 3      16.2    12.6     16.1      16.0        13.9       8.5          9.8
# 4      16.3     9.2     17.2      16.1        13.9       9.9          9.1
# 5      17.8    11.9     21.2      18.4        15.8      12.3          8.6
# 6      18.5     9.7     17.8      13.9        15.1      10.7         10.9
# 7      16.2    10.0     19.0      20.1        15.9      11.9         10.3
# 8      15.4    11.7     17.2      18.7        16.9      13.2         10.1
# 9      17.2    12.5     18.8      15.3        16.3      12.3          8.6
# 10     16.6    11.7     21.2      18.9        15.3      12.3          8.4
# 11     14.3     8.2     18.0      15.3        14.6      11.0          8.1
# ...

# %%
poverty.rename(columns=poverty.iloc[0])
# Out:
#             Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# Unnamed: 0  Alabama  Alaska  Arizona  Arkansas  California  Colorado
# 2019           12.9    10.2      9.9      14.1        10.1       9.3
# 2018             16    13.1     12.8      15.9        11.9       9.1
# 2017           15.3    12.1     13.6      14.9        12.1       8.9
# 2016           16.2    12.6     16.1        16        13.9       8.5
# 2015           16.3     9.2     17.2      16.1        13.9       9.9
# 2014           17.8    11.9     21.2      18.4        15.8      12.3
# 2013           18.5     9.7     17.8      13.9        15.1      10.7
# 2012           16.2      10       19      20.1        15.9      11.9
# 2011           15.4    11.7     17.2      18.7        16.9      13.2
# 2010           17.2    12.5     18.8      15.3        16.3      12.3
# 2009           16.6    11.7     21.2      18.9        15.3      12.3
# 2008           14.3     8.2       18      15.3        14.6        11
# ...

# %%
new_header = poverty.iloc[0] #grab the first row for the header
poverty = poverty[1:] #take the data less the header row
poverty.columns = new_header #set the header row as the df header
# Out:
# Unnamed: 0 Alabama Alaska Arizona Arkansas California Colorado Connecticut  \
# 2019          12.9   10.2     9.9     14.1       10.1      9.3         8.3
# 2018            16   13.1    12.8     15.9       11.9      9.1        10.2
# 2017          15.3   12.1    13.6     14.9       12.1      8.9        10.6
# 2016          16.2   12.6    16.1       16       13.9      8.5         9.8
# 2015          16.3    9.2    17.2     16.1       13.9      9.9         9.1
# 2014          17.8   11.9    21.2     18.4       15.8     12.3         8.6
# 2013          18.5    9.7    17.8     13.9       15.1     10.7        10.9
# 2012          16.2     10      19     20.1       15.9     11.9        10.3
# 2011          15.4   11.7    17.2     18.7       16.9     13.2        10.1
# 2010          17.2   12.5    18.8     15.3       16.3     12.3         8.6
# 2009          16.6   11.7    21.2     18.9       15.3     12.3         8.4
# ...

# %%
poverty.to_csv('./data/pct_pov_80_19.csv', index = False)

# %%
poverty
# Out:
# Unnamed: 0 Alabama Alaska Arizona Arkansas California Colorado Connecticut  \
# 2019          12.9   10.2     9.9     14.1       10.1      9.3         8.3
# 2018            16   13.1    12.8     15.9       11.9      9.1        10.2
# 2017          15.3   12.1    13.6     14.9       12.1      8.9        10.6
# 2016          16.2   12.6    16.1       16       13.9      8.5         9.8
# 2015          16.3    9.2    17.2     16.1       13.9      9.9         9.1
# 2014          17.8   11.9    21.2     18.4       15.8     12.3         8.6
# 2013          18.5    9.7    17.8     13.9       15.1     10.7        10.9
# 2012          16.2     10      19     20.1       15.9     11.9        10.3
# 2011          15.4   11.7    17.2     18.7       16.9     13.2        10.1
# 2010          17.2   12.5    18.8     15.3       16.3     12.3         8.6
# 2009          16.6   11.7    21.2     18.9       15.3     12.3         8.4
# ...
