# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

econ = pd.read_csv('cleaned_dataframes/df_m_median.csv')
econ.head()
# Out:
#    fips state_name   county        lat        lon  total_population  \
# 0  1001    Alabama  Autauga  32.534928 -86.642748             55049
# 1  1003    Alabama  Baldwin  30.727489 -87.722575            199510
# 2  1005    Alabama  Barbour  31.869589 -85.393213             26614
# 3  1007    Alabama     Bibb  32.998634 -87.126480             22572
# 4  1009    Alabama   Blount  33.980878 -86.567383             57704
#
#      area_sqmi  population_density_per_sqmi  percent_fair_or_poor_health  \
# 0   594.446120                    92.605533                    20.882987
# 1  1589.807425                   125.493187                    17.509134
# 2   884.875776                    30.076538                    29.591802
# 3   622.582355                    36.255444                    19.439724
# 4   644.806508                    89.490412                    21.745293
#
#    average_number_of_mentally_unhealthy_days  ...  \
# 0                                   4.654031  ...
# 1                                   4.304056  ...
# 2                                   5.185594  ...
# 3                                   4.551699  ...
# 4                                   4.891455  ...
#
#    percentile_rank_social_vulnerability  pct_overall_pov_19  fi_rate_18  \
# 0                                0.3773                12.1        15.6
# 1                                0.2757                10.1        12.9
# 2                                0.9847                27.1        21.9
# 3                                0.5737                20.3        15.1
# 4                                0.4986                16.3        13.6
#
#    ch_fi_rate_18  cpm_18  state_abr  \
# 0           21.4    3.33         AL
# 1           16.9    3.58         AL
# 2           32.0    3.12         AL
# 3           20.9    2.94         AL
# 4           19.1    3.14         AL
#
#    percent_of_adults_with_less_than_high_school_diploma  \
# 0                                               11.5
# 1                                                9.2
# 2                                               26.8
# 3                                               20.9
# 4                                               19.5
#
#    percent_of_adults_with_high_school_diploma_only  \
# 0                                             33.6
# 1                                             27.7
# 2                                             35.6
# 3                                             44.9
# 4                                             33.4
#
#    percent_of_adults_completing_some_college_or_associate_degree  \
# 0                                               28.4
# 1                                               31.3
# 2                                               26.0
# 3                                               23.8
# 4                                               34.0
#
#    percent_of_adults_with_bachelor_degree_or_higher
# 0                                              26.6
# 1                                              31.9
# 2                                              11.6
# 3                                              10.4
# 4                                              13.1
#
# [5 rows x 60 columns]

# %%
econ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Data columns (total 60 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   fips                                                           3140 non-null   int64
#  1   state_name                                                     3140 non-null   object
#  2   county                                                         3140 non-null   object
#  3   lat                                                            3140 non-null   float64
#  4   lon                                                            3140 non-null   float64
#  5   total_population                                               3140 non-null   int64
#  6   area_sqmi                                                      3140 non-null   float64
#  7   population_density_per_sqmi                                    3140 non-null   float64
#  8   percent_fair_or_poor_health                                    3140 non-null   float64
#  9   average_number_of_mentally_unhealthy_days                      3140 non-null   float64
#  10  percent_low_birthweight                                        3140 non-null   float64
#  11  percent_smokers                                                3140 non-null   float64
#  12  percent_adults_with_obesity                                    3140 non-null   float64
#  13  food_environment_index                                         3140 non-null   float64
#  14  percent_physically_inactive                                    3140 non-null   float64
#  15  percent_with_access_to_exercise_opportunities                  3140 non-null   float64
#  16  percent_uninsured                                              3140 non-null   float64
#  17  primary_care_physicians_rate                                   3140 non-null   float64
#  18  high_school_graduation_rate                                    3140 non-null   float64
#  19  percent_children_in_poverty                                    3140 non-null   float64
#  20  num_households_CHR                                             3140 non-null   float64
#  21  percent_single_parent_households_CHR                           3140 non-null   float64
#  22  violent_crime_rate                                             3140 non-null   float64
#  23  percent_severe_housing_problems                                3140 non-null   float64
#  24  severe_housing_cost_burden                                     3140 non-null   float64
#  25  life_expectancy                                                3140 non-null   float64
#  26  percent_adults_with_diabetes                                   3140 non-null   float64
#  27  percent_limited_access_to_healthy_foods                        3140 non-null   float64
#  28  median_household_income                                        3140 non-null   float64
#  29  percent_enrolled_in_free_or_reduced_lunch                      3140 non-null   float64
#  30  percent_homeowners                                             3140 non-null   float64
#  31  percent_severe_housing_cost_burden                             3140 non-null   float64
#  32  percent_black                                                  3140 non-null   float64
#  33  percent_american_indian_alaska_native                          3140 non-null   float64
#  34  percent_asian                                                  3140 non-null   float64
#  35  percent_native_hawaiian_other_pacific_islander                 3140 non-null   float64
#  36  percent_hispanic                                               3140 non-null   float64
#  37  percent_non_hispanic_white                                     3140 non-null   float64
#  38  percent_not_proficient_in_english                              3140 non-null   float64
#  39  percent_female                                                 3140 non-null   float64
#  40  percent_rural                                                  3140 non-null   float64
#  41  per_capita_income                                              3140 non-null   float64
#  42  percent_below_poverty                                          3140 non-null   float64
#  43  percent_unemployed_CDC                                         3140 non-null   float64
#  44  percent_no_highschool_diploma                                  3140 non-null   float64
#  45  percent_age_65_and_older                                       3140 non-null   float64
#  46  percent_age_17_and_younger                                     3140 non-null   float64
#  47  percent_disabled                                               3140 non-null   float64
#  48  percent_minorities                                             3140 non-null   float64
#  49  percent_limited_english_abilities                              3140 non-null   float64
#  50  percentile_rank_social_vulnerability                           3140 non-null   float64
#  51  pct_overall_pov_19                                             3140 non-null   float64
#  52  fi_rate_18                                                     3140 non-null   float64
#  53  ch_fi_rate_18                                                  3140 non-null   float64
#  54  cpm_18                                                         3140 non-null   float64
#  55  state_abr                                                      3140 non-null   object
#  56  percent_of_adults_with_less_than_high_school_diploma           3140 non-null   float64
#  57  percent_of_adults_with_high_school_diploma_only                3140 non-null   float64
#  58  percent_of_adults_completing_some_college_or_associate_degree  3140 non-null   float64
#  59  percent_of_adults_with_bachelor_degree_or_higher               3140 non-null   float64
# dtypes: float64(55), int64(2), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# # EDA
# Explore the features of the dataset

# %%
# Overlay scatterplots - blue is general rate, red is child rate
plt.figure(figsize = (30, 10))
sns.scatterplot(data = econ, x = 'state_name', y = 'fi_rate_18', palette = 'Blues')
sns.scatterplot(data = econ, x = 'state_name', y = 'ch_fi_rate_18', palette = 'Reds')

plt.title('Food Insecurity By State', size = 26)
plt.xlabel('State', size = 16)
plt.ylabel('Food Insecurity Rate (%)', size = 16)
plt.xticks(rotation = 45); # Credit to stackabuse - https://stackabuse.com/rotate-axis-labels-in-matplotlib/

plt.tight_layout();

# %%
# Check food insecurity against density
plt.figure(figsize = (30, 10))
g = sns.scatterplot(data = econ, x = 'population_density_per_sqmi', y = 'fi_rate_18', palette = 'Blues')
g = sns.scatterplot(data = econ, x = 'population_density_per_sqmi', y = 'ch_fi_rate_18', palette = 'Reds')

plt.title('Food Insecurity By Density', size = 26)
plt.xlabel('Population Density', size = 16)
plt.ylabel('Food Insecurity Rate (%)', size = 16)
g.set_xscale("log")

plt.tight_layout();

# %%
# Health Factors Against Food Insecurity
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (24, 10), sharey = True)

g = sns.scatterplot(data = econ, x = 'percent_low_birthweight', y = 'fi_rate_18', palette = 'Blues', ax = ax1)
g = sns.scatterplot(data = econ, x = 'percent_low_birthweight', y = 'ch_fi_rate_18', palette = 'Reds', ax = ax1)

h = sns.scatterplot(data = econ, x = 'percent_smokers', y = 'fi_rate_18', palette = 'Blues', ax = ax2)
h = sns.scatterplot(data = econ, x = 'percent_smokers', y = 'ch_fi_rate_18', palette = 'Reds', ax = ax2)

i = sns.scatterplot(data = econ, x = 'percent_adults_with_obesity', y = 'fi_rate_18', palette = 'Blues', ax = ax3)
i = sns.scatterplot(data = econ, x = 'percent_adults_with_obesity', y = 'ch_fi_rate_18', palette = 'Reds', ax = ax3)

g.title.set_text('Low Birthweight Against Food Insecurity')
h.title.set_text('Percent Smokers Against Food Insecurity')
i.title.set_text('Percent Adults With Obesity')

plt.tight_layout();
